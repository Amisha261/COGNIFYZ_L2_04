# %% [markdown]
# # Restaurant Chains

# %% [markdown]
# ## Importing python libraries

# %%
import pandas as pd

# %%
data=pd.read_csv("Dataset .csv")

# %%
data
# Out:
#       Restaurant ID           Restaurant Name  Country Code              City  \
# 0           6317637          Le Petit Souffle           162       Makati City
# 1           6304287          Izakaya Kikufuji           162       Makati City
# 2           6300002    Heat - Edsa Shangri-La           162  Mandaluyong City
# 3           6318506                      Ooma           162  Mandaluyong City
# 4           6314302               Sambo Kojin           162  Mandaluyong City
# ...             ...                       ...           ...               ...
# 9546        5915730               Naml۱ Gurme           208         ��stanbul
# 9547        5908749              Ceviz A��ac۱           208         ��stanbul
# 9548        5915807                     Huqqa           208         ��stanbul
# 9549        5916112               A���k Kahve           208         ��stanbul
# 9550        5927402  Walter's Coffee Roastery           208         ��stanbul
#
# ...

# %%
data.columns
# Out:
# Index(['Restaurant ID', 'Restaurant Name', 'Country Code', 'City', 'Address',
#        'Locality', 'Locality Verbose', 'Longitude', 'Latitude', 'Cuisines',
#        'Average Cost for two', 'Currency', 'Has Table booking',
#        'Has Online delivery', 'Is delivering now', 'Switch to order menu',
#        'Price range', 'Aggregate rating', 'Rating color', 'Rating text',
#        'Votes'],
#       dtype='object')

# %%
chain_count=data["Restaurant Name"].value_counts()
chain_count
# Out:
# Restaurant Name
# Cafe Coffee Day             83
# Domino's Pizza              79
# Subway                      63
# Green Chick Chop            51
# McDonald's                  48
#                             ..
# Odeon Social                 1
# Johnny Rockets               1
# House of Commons             1
# HotMess                      1
# Walter's Coffee Roastery     1
# Name: count, Length: 7446, dtype: int64

# %%
chain=chain_count[chain_count>1].index
chain
# Out:
# Index(['Cafe Coffee Day', 'Domino's Pizza', 'Subway', 'Green Chick Chop',
#        'McDonald's', 'Keventers', 'Pizza Hut', 'Giani', 'Baskin Robbins',
#        'Barbeque Nation',
#        ...
#        'Raasta', 'The Pint Room', 'Snacks Point', 'The Dosa King', 'Chokola',
#        'Town Hall', 'Halki Aanch', 'Snack Junction', 'Delhi Biryani Hut',
#        'Beliram Degchiwala'],
#       dtype='object', name='Restaurant Name', length=734)

# %%
chain_restaurants=data[data["Restaurant Name"].isin(chain)]
chain_restaurants
# Out:
#       Restaurant ID   Restaurant Name  Country Code              City  \
# 5          18189371      Din Tai Fung           162  Mandaluyong City
# 10          6309903  Silantro Fil-Mex           162        Pasig City
# 12          6318433  Silantro Fil-Mex           162       Quezon City
# 35          6601589        Coco Bambu            30         Bras�_lia
# 39          6600427        Coco Bambu            30         Bras�_lia
# ...             ...               ...           ...               ...
# 9517        6001980       Timboo Cafe           208            Ankara
# 9528        6003668       Timboo Cafe           208            Ankara
# 9534        6004089       D�_vero��lu           208            Ankara
# 9535        6000921       D�_vero��lu           208            Ankara
# 9538        5901782         Starbucks           208         ��stanbul
#
#                                                 Address  \
# 5     Ground Floor, Mega Fashion Hall, SM Megamall, ...
# ...

# %%
chain_avg_rating = chain_restaurants.groupby('Restaurant Name')['Aggregate rating'].mean().sort_values(ascending=False)
chain_avg_rating
# Out:
# Restaurant Name
# Talaga Sampireun                   4.900
# Silantro Fil-Mex                   4.850
# AB's Absolute Barbecues            4.850
# AB's - Absolute Barbecues          4.825
# Naturals Ice Cream                 4.800
#                                    ...
# Big Biryani                        0.000
# Flavours Kitchen                   0.000
# Anand Sweets                       0.000
# Radha Swami Shudh Vaishno Dhaba    0.000
# OCD - Online Cake Delivery         0.000
# Name: Aggregate rating, Length: 734, dtype: float64

# %%
chain_popularity = chain_restaurants.groupby('Restaurant Name')['Votes'].sum().sort_values(ascending=False)
chain_popularity
# Out:
# Restaurant Name
# Barbeque Nation              28142
# AB's - Absolute Barbecues    13400
# Big Chill                    10853
# Farzi Cafe                   10098
# Truffles                      9682
#                              ...
# Bikaner Misthan Bhandar          0
# Aap Ki Khatir                    0
# Street Cafe                      0
# Jyoti Sweets                     0
# Firangi Bake                     0
# Name: Votes, Length: 734, dtype: int64

# %%
chain_analysis = pd.DataFrame({
    'average_rating': chain_avg_rating,
    'total_reviews': chain_popularity
}).sort_values(by='average_rating', ascending=False)

# %%
chain_analysis
# Out:
#                                  average_rating  total_reviews
# Restaurant Name
# Talaga Sampireun                          4.900           5514
# Silantro Fil-Mex                          4.850           1364
# AB's Absolute Barbecues                   4.850           3151
# AB's - Absolute Barbecues                 4.825          13400
# Naturals Ice Cream                        4.800           3094
# ...                                         ...            ...
# Big Biryani                               0.000              1
# Flavours Kitchen                          0.000              3
# Anand Sweets                              0.000              3
# Radha Swami Shudh Vaishno Dhaba           0.000              6
# OCD - Online Cake Delivery                0.000              2
#
# [734 rows x 2 columns]

# %% [markdown]
# ## SUMMARY

# %% [markdown]
# Load the dataset:
#
# - Load the restaurant data into a DataFrame.
#
# Identify Chains:
#
# - Count the occurrences of each restaurant name to identify chains.
#
# Filter Chains:
#
# - Create a subset of the dataset containing only chain restaurants.
#
# Calculate Metrics:
#
# - Compute the average rating and total reviews for each chain.
#
# Combine and Analyze:
#
# - Merge the results and sort them to identify top chains based on ratings and popularity.
